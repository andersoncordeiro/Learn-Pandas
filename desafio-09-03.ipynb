# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../weatherHistory.csv')
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
dfnulls = df.isnull()

# %%
for column in dfnulls.columns.values.tolist():
    print(column)
    print(dfnulls[column].value_counts(), '\n')
# Out:
# Formatted Date
# False    96453
# Name: Formatted Date, dtype: int64
#
# Summary
# False    96453
# Name: Summary, dtype: int64
#
# Precip Type
# False    95936
# True       517
# Name: Precip Type, dtype: int64
#
# Temperature (C)
# False    96453
# Name: Temperature (C), dtype: int64
#
# Apparent Temperature (C)
# False    96453
# Name: Apparent Temperature (C), dtype: int64
#
# Humidity
# False    96453
# Name: Humidity, dtype: int64
#
# Wind Speed (km/h)
# False    96453
# Name: Wind Speed (km/h), dtype: int64
#
# Wind Bearing (degrees)
# False    96453
# Name: Wind Bearing (degrees), dtype: int64
#
# Visibility (km)
# False    96453
# Name: Visibility (km), dtype: int64
#
# Loud Cover
# False    96453
# Name: Loud Cover, dtype: int64
#
# Pressure (millibars)
# False    96453
# Name: Pressure (millibars), dtype: int64
#
# Daily Summary
# False    96453
# Name: Daily Summary, dtype: int64

# %%
df.isna().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df['Precip Type'].value_counts()
# Out:
# rain    85224
# snow    10712
# Name: Precip Type, dtype: int64

# %%
df['Precip Type'].replace(np.nan, "unknow", inplace=True)

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
df['Loud Cover'].value_counts()
# Out:
# 0.0    96453
# Name: Loud Cover, dtype: int64

# %%
df.drop(['Loud Cover'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                   251.0          15.8263               1015.13
# 1                   259.0          15.8263               1015.63
# 2                   204.0          14.9569               1015.94
# 3                   269.0          15.8263               1016.41
# 4                   259.0          15.8263               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
df['Wind Speed (km/h)'] = df['Wind Speed (km/h)']/df['Wind Speed (km/h)'].max()
df['Wind Bearing (degrees)'] = df['Wind Bearing (degrees)']/df['Wind Bearing (degrees)'].max()
df['Visibility (km)'] = df['Visibility (km)']/df['Visibility (km)'].max()
df['Pressure (millibars)'] = df['Pressure (millibars)']/df['Pressure (millibars)'].max()

# %%
dfnorm = df[['Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)']]

# %%
df['Wind Speed (km/h)']
# Out:
# 0        0.221130
# 1        0.223399
# 2        0.061523
# 3        0.220877
# 4        0.172970
#            ...
# 96448    0.172214
# 96449    0.158094
# 96450    0.140696
# 96451    0.164902
# 96452    0.092032
# Name: Wind Speed (km/h), Length: 96453, dtype: float64

# %%
#OHE
#ONE HOT ENCODER
dummy = pd.get_dummies(df['Precip Type'])
dummy.value_counts()
# Out:
# rain  snow  unknow
# 1     0     0         85224
# 0     1     0         10712
#       0     1           517
# dtype: int64

# %%
dummy.rename(columns={'rain':'precip-type-rain', 'snow':'precipt-type-snow', 'unkwnow':'precip-type-unknow'}, inplace=True)

# %%
dummy
# Out:
#        precip-type-rain  precipt-type-snow  unknow
# 0                     1                  0       0
# 1                     1                  0       0
# 2                     1                  0       0
# 3                     1                  0       0
# 4                     1                  0       0
# ...                 ...                ...     ...
# 96448                 1                  0       0
# 96449                 1                  0       0
# 96450                 1                  0       0
# 96451                 1                  0       0
# 96452                 1                  0       0
#
# [96453 rows x 3 columns]

# %%
df = pd.concat([df, dummy], axis=1)

# %%
df.corr()
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992629 -0.632255
# Apparent Temperature (C)         0.992629                  1.000000 -0.602571
# Humidity                        -0.632255                 -0.602571  1.000000
# Wind Speed (km/h)                0.008957                 -0.056650 -0.224951
# Wind Bearing (degrees)           0.029988                  0.029031  0.000735
# Visibility (km)                  0.392847                  0.381718 -0.369173
# Pressure (millibars)            -0.005447                 -0.000219  0.005454
# precip-type-rain                 0.553873                  0.555889 -0.228314
# precipt-type-snow               -0.562620                 -0.565207  0.232113
# unknow                          -0.011833                 -0.009554  0.004044
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.008957                0.029988
# Apparent Temperature (C)          -0.056650                0.029031
# Humidity                          -0.224951                0.000735
# Wind Speed (km/h)                  1.000000                0.103822
# Wind Bearing (degrees)             0.103822                1.000000
# Visibility (km)                    0.100749                0.047594
# Pressure (millibars)              -0.049263               -0.011651
# precip-type-rain                   0.063988                0.041406
# precipt-type-snow                 -0.067928               -0.041984
# unknow                             0.011240               -0.001210
#
#                           Visibility (km)  Pressure (millibars)  \
# Temperature (C)                  0.392847             -0.005447
# Apparent Temperature (C)         0.381718             -0.000219
# Humidity                        -0.369173              0.005454
# Wind Speed (km/h)                0.100749             -0.049263
# Wind Bearing (degrees)           0.047594             -0.011651
# Visibility (km)                  1.000000              0.059818
# Pressure (millibars)             0.059818              1.000000
# precip-type-rain                 0.317667             -0.011103
# precipt-type-snow               -0.312875              0.009008
# unknow                          -0.048994              0.010006
#
#                           precip-type-rain  precipt-type-snow    unknow
# Temperature (C)                   0.553873          -0.562620 -0.011833
# Apparent Temperature (C)          0.555889          -0.565207 -0.009554
# Humidity                         -0.228314           0.232113  0.004044
# Wind Speed (km/h)                 0.063988          -0.067928  0.011240
# Wind Bearing (degrees)            0.041406          -0.041984 -0.001210
# Visibility (km)                   0.317667          -0.312875 -0.048994
# Pressure (millibars)             -0.011103           0.009008  0.010006
# precip-type-rain                  1.000000          -0.973759 -0.202239
# precipt-type-snow                -0.973759           1.000000 -0.025947
# unknow                           -0.202239          -0.025947  1.000000

# %%
df.corr()
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992629 -0.632255
# Apparent Temperature (C)         0.992629                  1.000000 -0.602571
# Humidity                        -0.632255                 -0.602571  1.000000
# Wind Speed (km/h)                0.008957                 -0.056650 -0.224951
# Wind Bearing (degrees)           0.029988                  0.029031  0.000735
# Visibility (km)                  0.392847                  0.381718 -0.369173
# Pressure (millibars)            -0.005447                 -0.000219  0.005454
# precip-type-rain                 0.553873                  0.555889 -0.228314
# precipt-type-snow               -0.562620                 -0.565207  0.232113
# unknow                          -0.011833                 -0.009554  0.004044
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.008957                0.029988
# Apparent Temperature (C)          -0.056650                0.029031
# Humidity                          -0.224951                0.000735
# Wind Speed (km/h)                  1.000000                0.103822
# Wind Bearing (degrees)             0.103822                1.000000
# Visibility (km)                    0.100749                0.047594
# Pressure (millibars)              -0.049263               -0.011651
# precip-type-rain                   0.063988                0.041406
# precipt-type-snow                 -0.067928               -0.041984
# unknow                             0.011240               -0.001210
#
#                           Visibility (km)  Pressure (millibars)  \
# Temperature (C)                  0.392847             -0.005447
# Apparent Temperature (C)         0.381718             -0.000219
# Humidity                        -0.369173              0.005454
# Wind Speed (km/h)                0.100749             -0.049263
# Wind Bearing (degrees)           0.047594             -0.011651
# Visibility (km)                  1.000000              0.059818
# Pressure (millibars)             0.059818              1.000000
# precip-type-rain                 0.317667             -0.011103
# precipt-type-snow               -0.312875              0.009008
# unknow                          -0.048994              0.010006
#
#                           precip-type-rain  precipt-type-snow    unknow
# Temperature (C)                   0.553873          -0.562620 -0.011833
# Apparent Temperature (C)          0.555889          -0.565207 -0.009554
# Humidity                         -0.228314           0.232113  0.004044
# Wind Speed (km/h)                 0.063988          -0.067928  0.011240
# Wind Bearing (degrees)            0.041406          -0.041984 -0.001210
# Visibility (km)                   0.317667          -0.312875 -0.048994
# Pressure (millibars)             -0.011103           0.009008  0.010006
# precip-type-rain                  1.000000          -0.973759 -0.202239
# precipt-type-snow                -0.973759           1.000000 -0.025947
# unknow                           -0.202239          -0.025947  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df[['Humidity', 'Temperature (C)']].corr()
# Out:
#                  Humidity  Temperature (C)
# Humidity         1.000000        -0.632255
# Temperature (C) -0.632255         1.000000

# %%
sns.regplot(x='Humidity', y='Temperature (C)', data=df)
plt.ylim(0,)
# Out:
# (0.0, 42.99194444444444)

# %%
dfSample = df.sample(1000)
sns.regplot(x='Humidity', y='Temperature (C)', data=dfSample)
plt.ylim(0,)
# Out:
# (0.0, 38.57277777777778)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
X = df[['Humidity']]
Y = df['Temperature (C)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30) #holdout

# %%
lm.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.coef_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af3abf2152ad> in <module>
# ----> 1 lm.coef_
#
# NameError: name 'lm' is not defined

# %%
lm.score(X_train, Y_train)
# Out:
# 0.3994992030143907

# %%
y_pred = lm.predict(X_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
# y_pred, y_test

print('R2:', r2_score(Y_test, y_pred))
print('MAE: ', mean_absolute_error(Y_test, y_pred))
print('MSE:', mean_squared_error(Y_test, y_pred))
# Out:
# R2: 0.40031160289523315
# MAE:  6.033015997165296
# MSE: 54.86920758316281

# %%
# RMSE
